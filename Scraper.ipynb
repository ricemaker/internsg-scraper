# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def get_internship(start_page,stop_page):
    #create blank dataframe
    df = pd.DataFrame(columns = ["Company", "Title", "Period", "Location","Link"])

    #starting the loop (modify the range to the page numbers targeted)
    for i in range(start_page,stop_page + 1):
        url = "https://www.internsg.com/jobs/{}/".format(i)
        html = requests.get(url).text
        soup = BeautifulSoup(html)

        #getting rid of all span tags after the company name, period, location
        for x in soup.find_all("span",["text-monospace badge badge-warning badge-tooltip",
                                       "text-monospace badge badge-info badge-tooltip mr-1",
                                      "text-monospace badge badge-primary badge-tooltip mr-1",
                                      "text-monospace badge badge-secondary badge-tooltip mr-1",
                                      "text-monospace badge badge-dark badge-tooltip mr-1"]):
            x.decompose()

        #getting a list of company names, job titles period, location, and links
        cjp = [[element.text for element in soup.find_all("div", "ast-col-md-3")]
         [i::3] for i in range(3)]
        location = [element.text for element in soup.find_all("span","job-listing-dt")]
        link = [link.find("a").get("href") for link in soup.find_all("div","ast-col-md-3") if link.find("a") != None]

        #appending to blank dataframe
        pg = pd.DataFrame(cjp).set_index(0).transpose().reset_index(drop = True)
        pg["Location"] = location
        pg["Link"] = link
        df = df.append(pg,ignore_index = True)
        
        #scraping the individual entry pages for the posting date
        pdate = [BeautifulSoup(requests.get(url).text)
                 .find_all("div", "ast-row p-3 detail-even")[1]
                 .text[14:-1] 
                 for url in df["Link"]]
        
        # adding the column posting dates to the dataframe
        df["Posting"] = pdate
    return df

# %%
get_internship(1,1)
# Out:
# 0                              Company  \
# 0    Land Transport Services Pte. Ltd.
# 1                      ZEM Productions
# 2   Digital Treasures Center Pte. Ltd.
# 3   Digital Treasures Center Pte. Ltd.
# 4       Wishbone Digital Group Pte Ltd
# 5                    Gushcloud Pte Ltd
# 6            Campari Singapore Pte Ltd
# 7                        VLC Marketing
# 8                          BN Holdings
# 9                                  DMK
# 10         SEKIM International PTE Ltd
# 11               Sigma-Aldrich Pte Ltd
# 12              Prestige Biopharma Ltd
# 13                       TAEL Partners
# 14         Unicorn Financial Solutions
# 15             Top Middle Base Pte Ltd
# 16                   Perx Technologies
# 17             Advisors Alliance Group
# 18                      SLM Visioncare
# 19                    Decacorn Capital
# 20                Lizard Storm Pte Ltd
# 21                Fun Learners' School
#
# 0                                               Title  \
# 0         Transport / Logistics Administrative Intern
# 1                         Business Development Intern
# 2                           Business Operation Intern
# 3                                       DevOps Intern
# 4                            Digital Marketing Intern
# 5                            Account Marketing Intern
# 6                                    Marketing Intern
# 7                  B2B Corporate Sales Representative
# 8   (SIM/SUSS/Fresh Grads) - Business Apprenticesh...
# 9     Public Relations (PR) and Communications Intern
# 10      Digital Solutions Business Development Intern
# 11                             Facility Support - Lab
# 12                             Clinical Trials Intern
# 13                              Private Equity Intern
# 14                        Fee-based Financial Planner
# 15              Design and Product Development Intern
# 16            Software Engineer Intern (Server Infra)
# 17                      Financial Services Internship
# 18                            Copywriter cum Designer
# 19                     Venture Associate - Internship
